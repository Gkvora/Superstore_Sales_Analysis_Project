# %% [markdown]
# # Name : Gautam Vora
# # Project Name : Superstore Analysis

# %% [markdown]
# ### Importing all libraries required in this project

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Readng the Dataset

# %%
df=pd.read_csv("C:\\Users\\A\\Superstore Data.csv")

# %%
df
# Out:
#                        Order ID  Order Date   Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954  11-11-2014  13-11-2014     First Class
# 1        IN-2014-JR162107-41675  05-02-2014  07-02-2014    Second Class
# 2        IN-2014-CR127307-41929  17-10-2014  18-10-2014     First Class
# 3       ES-2014-KM1637548-41667  28-01-2014  30-01-2014     First Class
# 4       SG-2014-RH9495111-41948  05-11-2014  06-11-2014        Same Day
# ...                         ...         ...         ...             ...
# 51285   IN-2015-KE1642066-42174  19-06-2015  19-06-2015        Same Day
# 51286  US-2014-ZD21925140-41765  06-05-2014  10-05-2014  Standard Class
# 51287  CA-2012-ZD21925140-41147  26-08-2012  31-08-2012    Second Class
# 51288   MX-2013-RB1979518-41322  17-02-2013  21-02-2013  Standard Class
# 51289   MX-2013-MC1810093-41416  22-05-2013  26-05-2013    Second Class
#
#         Customer ID       Customer Name      Segment           City  \
# ...

# %% [markdown]
# ### Exploring Data

# %%
df.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  11-11-2014  13-11-2014   First Class
# 1    IN-2014-JR162107-41675  05-02-2014  07-02-2014  Second Class
# 2    IN-2014-CR127307-41929  17-10-2014  18-10-2014   First Class
# 3   ES-2014-KM1637548-41667  28-01-2014  30-01-2014   First Class
# 4   SG-2014-RH9495111-41948  05-11-2014  06-11-2014      Same Day
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          Dakar
#
#              State        Country  ...    Category Sub-Category  \
# 0         Oklahoma  United States  ...  Technology       Phones
# ...

# %%
df.tail()
# Out:
#                        Order ID  Order Date   Ship Date       Ship Mode  \
# 51285   IN-2015-KE1642066-42174  19-06-2015  19-06-2015        Same Day
# 51286  US-2014-ZD21925140-41765  06-05-2014  10-05-2014  Standard Class
# 51287  CA-2012-ZD21925140-41147  26-08-2012  31-08-2012    Second Class
# 51288   MX-2013-RB1979518-41322  17-02-2013  21-02-2013  Standard Class
# 51289   MX-2013-MC1810093-41416  22-05-2013  26-05-2013    Second Class
#
#         Customer ID       Customer Name      Segment           City  \
# 51285    KE-1642066     Katrina Edelman    Corporate           Kure
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer    Chattanooga
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer  San Francisco
# 51288    RB-1979518          Ross Baird  Home Office       Valinhos
# 51289    MC-1810093       Mick Crebagga     Consumer       Tipitapa
#
#             State        Country  ...         Category Sub-Category  \
# ...

# %%
df.sample(2)
# Out:
#                       Order ID  Order Date   Ship Date       Ship Mode  \
# 32426  ZA-2015-LS6975146-42077  14-03-2015  16-03-2015     First Class
# 34836  MX-2014-LW1682518-41719  21-03-2014  26-03-2014  Standard Class
#
#       Customer ID     Customer Name      Segment     City  \
# 32426  LS-6975146  Lindsay Shagiari  Home Office    Kitwe
# 34836  LW-1682518    Laurel Workman    Corporate  Mossoró
#
#                      State Country  ...         Category Sub-Category  \
# 32426           Copperbelt  Zambia  ...  Office Supplies      Binders
# 34836  Rio Grande do Norte  Brazil  ...        Furniture  Furnishings
#
#                            Product Name Sales Quantity Discount  Profit  \
# 32426      Wilson Jones Binder, Durable    29        2      0.0       1
# 34836  Rubbermaid Photo Frame, Duo Pack    34        1      0.0      11
#
#        Shipping Cost  Order Priority  Delivery Days
# 32426              4        Critical              2
# ...

# %% [markdown]
# ### How big is the dataset ?

# %%
df.shape
# Out:
# (51290, 23)

# %% [markdown]
# ### Conclusion :
# Here We have 51290 Rows / Records and 23 Columns / Attributes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51290 non-null  object
#  1   Order Date      51290 non-null  object
#  2   Ship Date       51290 non-null  object
#  3   Ship Mode       51290 non-null  object
#  4   Customer ID     51290 non-null  object
#  5   Customer Name   51290 non-null  object
#  6   Segment         51290 non-null  object
#  7   City            51290 non-null  object
#  8   State           51290 non-null  object
#  9   Country         51290 non-null  object
#  10  Region          51290 non-null  object
#  11  Market          51290 non-null  object
#  12  Product ID      51290 non-null  object
#  13  Category        51290 non-null  object
#  14  Sub-Category    51290 non-null  object
#  15  Product Name    51290 non-null  object
#  16  Sales           51290 non-null  int64
# ...

# %% [markdown]
# ### Descriptive Statistics :

# %%
df.describe()
# Out:
#               Sales      Quantity      Discount        Profit  Shipping Cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     245.974303      3.476545      0.142908     28.361006      25.985806
# std      487.561293      2.278766      0.212280    174.193005      57.252000
# min        0.000000      1.000000      0.000000  -6599.000000       1.000000
# 25%       30.000000      2.000000      0.000000      0.000000       2.000000
# 50%       85.000000      3.000000      0.000000      9.000000       7.000000
# 75%      251.000000      5.000000      0.200000     36.000000      24.000000
# max    22638.000000     14.000000      0.850000   8399.000000     933.000000
#
#        Delivery Days
# count   51290.000000
# mean        3.969370
# std         1.729437
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         7.000000

# %% [markdown]
# ### Conlusion :
# Thus, here Average of sales amount is 245.974303
#
# Average of profit is 28.361006

# %% [markdown]
# ### Dropping Duplicate data (Rows/ Records)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
df[df.duplicated()]
# Out:
#                        Order ID  Order Date   Ship Date       Ship Mode  \
# 36524  ES-2014-SR20740120-41804  14-06-2014  21-06-2014  Standard Class
# 39293    KE-2014-PC900069-41693  23-02-2014  25-02-2014    Second Class
# 45322    ID-2012-AR105107-41031  02-05-2012  08-05-2012  Standard Class
#
#        Customer ID   Customer Name      Segment      City            State  \
# 36524  SR-20740120   Steven Roelle  Home Office    Madrid           Madrid
# 39293    PC-900069   Pauline Chand  Home Office     Thika          Central
# 45322    AR-105107  Andrew Roberts     Consumer  Armidale  New South Wales
#
#          Country  ...         Category Sub-Category  \
# 36524      Spain  ...  Office Supplies      Binders
# 39293      Kenya  ...  Office Supplies    Envelopes
# 45322  Australia  ...  Office Supplies      Binders
#
#                                  Product Name Sales Quantity Discount  Profit  \
# 36524      Wilson Jones 3-Hole Punch, Economy    83        3      0.0      27
# ...

# %%
df=df.drop_duplicates(keep='first')

# %%
df.head()
# Out:
#                    Order ID  Order Date   Ship Date     Ship Mode  \
# 0  CA-2014-AB10015140-41954  11-11-2014  13-11-2014   First Class
# 1    IN-2014-JR162107-41675  05-02-2014  07-02-2014  Second Class
# 2    IN-2014-CR127307-41929  17-10-2014  18-10-2014   First Class
# 3   ES-2014-KM1637548-41667  28-01-2014  30-01-2014   First Class
# 4   SG-2014-RH9495111-41948  05-11-2014  06-11-2014      Same Day
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          Dakar
#
#              State        Country  ...    Category Sub-Category  \
# 0         Oklahoma  United States  ...  Technology       Phones
# ...

# %%
# After removing Duplicate values
df.shape
# Out:
# (51287, 23)

# %% [markdown]
# ### Conclusion :
# Thus, our rows/records reduced from 51290 to 51287

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Delivery Days     0
# dtype: int64

# %% [markdown]
# ### Conclusion :
# Here there is no Null value present in data.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51287 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51287 non-null  object
#  1   Order Date      51287 non-null  object
#  2   Ship Date       51287 non-null  object
#  3   Ship Mode       51287 non-null  object
#  4   Customer ID     51287 non-null  object
#  5   Customer Name   51287 non-null  object
#  6   Segment         51287 non-null  object
#  7   City            51287 non-null  object
#  8   State           51287 non-null  object
#  9   Country         51287 non-null  object
#  10  Region          51287 non-null  object
#  11  Market          51287 non-null  object
#  12  Product ID      51287 non-null  object
#  13  Category        51287 non-null  object
#  14  Sub-Category    51287 non-null  object
#  15  Product Name    51287 non-null  object
#  16  Sales           51287 non-null  int64
# ...

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],infer_datetime_format=True)
df['Ship Date']=pd.to_datetime(df['Ship Date'],infer_datetime_format=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51287 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51287 non-null  object
#  1   Order Date      51287 non-null  datetime64[ns]
#  2   Ship Date       51287 non-null  datetime64[ns]
#  3   Ship Mode       51287 non-null  object
#  4   Customer ID     51287 non-null  object
#  5   Customer Name   51287 non-null  object
#  6   Segment         51287 non-null  object
#  7   City            51287 non-null  object
#  8   State           51287 non-null  object
#  9   Country         51287 non-null  object
#  10  Region          51287 non-null  object
#  11  Market          51287 non-null  object
#  12  Product ID      51287 non-null  object
#  13  Category        51287 non-null  object
#  14  Sub-Category    51287 non-null  object
#  15  Product Name    51287 non-null  object
# ...

# %%
df['Order Month']=df['Order Date'].dt.month
df['Order Year']=df['Order Date'].dt.year

# %%
df.head()
# Out:
#                    Order ID Order Date  Ship Date     Ship Mode   Customer ID  \
# 0  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class  AB-100151402
# 1    IN-2014-JR162107-41675 2014-05-02 2014-02-07  Second Class     JR-162107
# 2    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class     CR-127307
# 3   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class    KM-1637548
# 4   SG-2014-RH9495111-41948 2014-05-11 2014-11-06      Same Day    RH-9495111
#
#       Customer Name      Segment           City            State  \
# 0     Aaron Bergman     Consumer  Oklahoma City         Oklahoma
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#          Country  ...                               Product Name Sales  \
# ...

# %%
df.drop('Ship Date',axis=1,inplace=True)
df.drop('Order Date',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51287 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51287 non-null  object
#  1   Ship Mode       51287 non-null  object
#  2   Customer ID     51287 non-null  object
#  3   Customer Name   51287 non-null  object
#  4   Segment         51287 non-null  object
#  5   City            51287 non-null  object
#  6   State           51287 non-null  object
#  7   Country         51287 non-null  object
#  8   Region          51287 non-null  object
#  9   Market          51287 non-null  object
#  10  Product ID      51287 non-null  object
#  11  Category        51287 non-null  object
#  12  Sub-Category    51287 non-null  object
#  13  Product Name    51287 non-null  object
#  14  Sales           51287 non-null  int64
#  15  Quantity        51287 non-null  int64
#  16  Discount        51287 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Region', 'Market', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority',
#        'Delivery Days', 'Order Month', 'Order Year'],
#       dtype='object')

# %% [markdown]
# ### Looking for Numerical and Categorical/Ordinal variables or attributes

# %%
numeric_features =[feature for feature in df.columns if df[feature].dtype != 'O' ]

# %%
numeric_features
# Out:
# ['Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Delivery Days',
#  'Order Month',
#  'Order Year']

# %%
df[numeric_features]
# Out:
#        Sales  Quantity  Discount  Profit  Shipping Cost  Delivery Days  \
# 0        221         2       0.0      62             40              2
# 1       3709         9       0.1    -288            923              2
# 2       5175         9       0.1     919            915              1
# 3       2892         5       0.1     -96            910              2
# 4       2832         8       0.0     311            903              1
# ...      ...       ...       ...     ...            ...            ...
# 51285     65         5       0.0       4              1              0
# 51286     16         5       0.2       3              1              4
# 51287      8         2       0.0       2              1              5
# 51288     13         2       0.0       2              1              4
# 51289     61         3       0.0       1              1              4
#
#        Order Month  Order Year
# 0               11        2014
# 1                5        2014
# ...

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['Order ID',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'City',
#  'State',
#  'Country',
#  'Region',
#  'Market',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Order Priority']

# %%
df[categorical_features]
# Out:
#                        Order ID       Ship Mode   Customer ID  \
# 0      CA-2014-AB10015140-41954     First Class  AB-100151402
# 1        IN-2014-JR162107-41675    Second Class     JR-162107
# 2        IN-2014-CR127307-41929     First Class     CR-127307
# 3       ES-2014-KM1637548-41667     First Class    KM-1637548
# 4       SG-2014-RH9495111-41948        Same Day    RH-9495111
# ...                         ...             ...           ...
# 51285   IN-2015-KE1642066-42174        Same Day    KE-1642066
# 51286  US-2014-ZD21925140-41765  Standard Class  ZD-219251408
# 51287  CA-2012-ZD21925140-41147    Second Class  ZD-219251404
# 51288   MX-2013-RB1979518-41322  Standard Class    RB-1979518
# 51289   MX-2013-MC1810093-41416    Second Class    MC-1810093
#
#             Customer Name      Segment           City            State  \
# 0           Aaron Bergman     Consumer  Oklahoma City         Oklahoma
# 1           Justin Ritter    Corporate     Wollongong  New South Wales
# ...

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    31286
# Technology         10141
# Furniture           9860
# Name: Category, dtype: int64

# %%
df['Category'].value_counts(normalize=True)*100
# Out:
# Office Supplies    61.001813
# Technology         19.773042
# Furniture          19.225145
# Name: Category, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print('#'*50)
# Out:
# Order ID:CA-2015-SV20365140-42268    0.027297
# NI-2015-TC1098095-42033     0.025348
# TO-2015-AB600131-42299      0.025348
# MX-2015-PO1885082-42279     0.025348
# IN-2013-TB21055113-41562    0.025348
#                               ...
# ES-2012-HG1502548-40992     0.001950
# ES-2015-JS1559548-42066     0.001950
# ES-2012-ME1732045-41076     0.001950
# CA-2015-EA14035140-42217    0.001950
# MX-2013-MC1810093-41416     0.001950
# Name: Order ID, Length: 25728, dtype: float64
# ##################################################
# Ship Mode:Standard Class    60.001560
# Second Class      20.098660
# First Class       14.633338
# Same Day           5.266442
# Name: Ship Mode, dtype: float64
# ##################################################
# Customer ID:SV-203651406    0.050695
# WB-218501404    0.046795
# AP-109151404    0.044846
# EM-1396082      0.040946
# CS-121757       0.038996
#                   ...
# LW-7215110      0.001950
# XP-2186531      0.001950
# ...

# %% [markdown]
# ### Category Wise Order Counts

# %%
s= sns.countplot(x=df['Category'],order=df['Category'].value_counts(ascending=False).index);
values_ = df['Category'].value_counts(ascending=False).values
s.bar_label(container=s.containers[0], labels=values_)
plt.show()

# %% [markdown]
# ### Sub-Category Wise Order Counts

# %%
plt.figure(figsize=(12,7))
s= sns.countplot(y=df['Sub-Category'],order=df['Sub-Category'].value_counts(ascending=False).index);
values_ = df['Sub-Category'].value_counts(ascending=False).values
s.bar_label(container=s.containers[0], labels=values_)
plt.title('Sub-Category Wise Order Count',fontsize=15)
plt.show()

# %% [markdown]
# ### Segment Wise Order Count

# %%
plt.figure(figsize=(20,10))
a=sns.countplot(x='Sub-Category',hue='Segment',data=df)
for i in a.containers:
    a.bar_label(i)
plt.title('Segment Wise Order Count',fontsize=15)
plt.show()

# %% [markdown]
# ### Conclusion :
# Here by looking this graph we can say that,
# * highest orders are Office Supplies from Category.
# * 80% of orders are for 8 sub-categories.

# %%
df.head(4)
# Out:
#                    Order ID     Ship Mode   Customer ID     Customer Name  \
# 0  CA-2014-AB10015140-41954   First Class  AB-100151402     Aaron Bergman
# 1    IN-2014-JR162107-41675  Second Class     JR-162107     Justin Ritter
# 2    IN-2014-CR127307-41929   First Class     CR-127307      Craig Reiter
# 3   ES-2014-KM1637548-41667   First Class    KM-1637548  Katherine Murray
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
#
#          Market  ...                               Product Name Sales  \
# 0          USCA  ...                           Samsung Convoy 3   221
# ...

# %%
category=df.groupby('Category')['Sales'].sum().sort_values(ascending=False).reset_index().head(10)
plt.pie(category['Sales'],labels=category['Category'],autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Conclusion:
# Sales of Technology is the highest percntage (37.6 %) in all Category

# %%
sub_category=df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).reset_index().head(10)
plt.pie(sub_category['Sales'],labels=sub_category['Sub-Category'],autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Conclusion:
# Sales of Phones isthe highest percntage (15.4 %) in all Sub-Category

# %% [markdown]
# ### Category Wise Total Sales and Profit Performance

# %%
c1=df['Category'].unique()
c1
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
# Category WIse Total Sales
y4 = df.groupby(['Category'])['Sales'].sum()
y4
# Out:
# Category
# Furniture          4105451
# Office Supplies    3771363
# Technology         4739090
# Name: Sales, dtype: int64

# %%
# Category WIse Total Profit
y4_prof = df.groupby(['Category'])['Profit'].sum()
y4_prof
# Out:
# Category
# Furniture          283308
# Office Supplies    510242
# Technology         661049
# Name: Profit, dtype: int64

# %%
# Category WIse Total Discount
y4_disc = df.groupby(['Category'])['Discount'].sum()
y4_disc
# Out:
# Category
# Furniture          1656.230
# Office Supplies    4300.890
# Technology         1372.508
# Name: Discount, dtype: float64

# %%
fig,(dx1,dx2,dx3) = plt.subplots(1,3,figsize=(20,6))
dx1.bar(c1,y4,color = ['blue','red','green'])
dx2.bar(c1,y4_prof,color = ['blue','red','green'])
dx3.bar(c1,y4_disc,color = ['blue','red','green'])
dx1.set_title('Category WIse Total Sales', fontsize = 15)
dx2.set_title('Category WIse Total Profit',fontsize = 15)
dx3.set_title('Category WIse Total Discount',fontsize = 15)
plt.show()

# %% [markdown]
# ## Conclusion :
# Thus, from these graphs we may say that Total sales and Profit are Maximum for Technology Category , though we are giving maximum Discount to Office Suppliers Category

# %% [markdown]
# ### Top 10 Countries, in which the most sales took place

# %%
sales_=df.groupby('Country')['Sales'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(15,7))
s=sns.barplot(x="Country",y='Sales',data=sales_)
plt.xlabel("Countries", fontsize =15)
plt.ylabel("Total Sales",fontsize =15)
plt.title("Countries V/s. Sales",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Top 10 States, in which the most sales took place

# %%
sales_=df.groupby('State')['Sales'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(15,7))
s=sns.barplot(x="State",y='Sales',data=sales_)
plt.xlabel("State", fontsize =15)
plt.ylabel("Total Sales",fontsize =15)
plt.title("State V/s. Sales",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Top 10 Cities, in which the most sales took place

# %%
sales_=df.groupby('City')['Sales'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(15,7))
s=sns.barplot(x="City",y='Sales',data=sales_)
plt.xlabel("City", fontsize =15)
plt.ylabel("Total Sales",fontsize =15)
plt.title("City V/s. Sales",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Top 10 Countries, in which the most profits took place

# %%
profit_=df.groupby('Country')['Profit'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(15,7))
s=sns.barplot(x="Country",y='Profit',data=profit_)
plt.xlabel("Countries", fontsize =15)
plt.ylabel("Total Profit",fontsize =15)
plt.title("Countries V/s. Profit",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Top 10 States, in which the most profits took place

# %%
profit_=df.groupby('State')['Profit'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(20,10))
s=sns.barplot(x="State",y='Profit',data=profit_)
plt.xlabel("State", fontsize =15)
plt.ylabel("Total Profit",fontsize =15)
plt.title("State V/s. Profit",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Top 10 Cities, in which the most profits took place

# %%
profit_=df.groupby('City')['Profit'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(15,7))
s=sns.barplot(x="City",y='Profit',data=profit_)
plt.xlabel("City", fontsize =15)
plt.ylabel("Total Profit",fontsize =15)
plt.title("City V/s. Profit",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %%
df.head()
# Out:
#                    Order ID     Ship Mode   Customer ID     Customer Name  \
# 0  CA-2014-AB10015140-41954   First Class  AB-100151402     Aaron Bergman
# 1    IN-2014-JR162107-41675  Second Class     JR-162107     Justin Ritter
# 2    IN-2014-CR127307-41929   First Class     CR-127307      Craig Reiter
# 3   ES-2014-KM1637548-41667   First Class    KM-1637548  Katherine Murray
# 4   SG-2014-RH9495111-41948      Same Day    RH-9495111       Rick Hansen
#
#        Segment           City            State        Country          Region  \
# 0     Consumer  Oklahoma City         Oklahoma  United States      Central US
# 1    Corporate     Wollongong  New South Wales      Australia         Oceania
# 2     Consumer       Brisbane       Queensland      Australia         Oceania
# 3  Home Office         Berlin           Berlin        Germany  Western Europe
# 4     Consumer          Dakar            Dakar        Senegal  Western Africa
#
# ...

# %% [markdown]
# ### Year wise Highest and Lowest order

# %%
year1=df['Order Year'].value_counts().reset_index()
s=sns.barplot(year1['index'],year1['Order Year'])
plt.xlabel("Year", fontsize =15)
plt.ylabel("Total Order",fontsize =15)
plt.title("Yearly Orders",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Month wise Highest and Lowest order

# %%
year1=df['Order Month'].value_counts().reset_index()
s=sns.barplot(year1['index'],year1['Order Month'])
plt.xlabel("Month", fontsize =15)
plt.ylabel("Total Order",fontsize =15)
plt.title("Monthly Orders",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Conclusion :
# Here by looking these graphs we can say that ,
#
# The maximum order comes in the year '2015' and the maximum order comes in the 'november' month.

# %% [markdown]
# ### Ship Mode and it's impact on sales

# %%
x=df['Ship Mode'].unique()
x.sort()
x
# Out:
# array(['First Class', 'Same Day', 'Second Class', 'Standard Class'],
#       dtype=object)

# %%
# Shipmode wise total sales
y_sal = df.groupby(['Ship Mode'])['Sales'].sum()
y_sal
# Out:
# Ship Mode
# First Class       1827098
# Same Day           665804
# Second Class      2560306
# Standard Class    7562696
# Name: Sales, dtype: int64

# %%
# Shipmode wise total profit
y_prof = df.groupby(['Ship Mode'])['Profit'].sum()
y_prof
# Out:
# Ship Mode
# First Class       206257
# Same Day           75464
# Second Class      289970
# Standard Class    882908
# Name: Profit, dtype: int64

# %%
# Shipmode wise total discount
y_dis = df.groupby(['Ship Mode'])['Discount'].sum()
y_dis
# Out:
# Ship Mode
# First Class       1117.478
# Same Day           387.662
# Second Class      1449.656
# Standard Class    4374.832
# Name: Discount, dtype: float64

# %%
fig,(a1, a2, a3) =  plt.subplots(1,3,figsize=(20,7))
a1.bar(x,y_sal,color =['blue','red','orange','green'])                          
a2.bar(x,y_prof,color=['blue','red','orange','green'])
a3.bar(x,y_dis,color=['blue','red','orange','green'])
a1.set_title('Shipmodewise Total Sales')
a2.set_title('Shipeodewise Total Profit')
a3.set_title('Shipmodewise Total Discount')
plt.show()

# %% [markdown]
# ### Conclusion :
# Here by looking these graphs we can say that ,
#
# * Total sales for Standard Class is High and that will result into High Profit and High Discount
# * So we have to use this strategies to imporve our sales and profit

# %% [markdown]
# ### Segment wise sales and it's impact

# %%
# Segment Wise Total Sales
s1 = df['Segment'].unique()
s1
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
y2 = df.groupby(['Segment'])['Sales'].sum()
y2
# Out:
# Segment
# Consumer       6494249
# Corporate      3816759
# Home Office    2304896
# Name: Sales, dtype: int64

# %%
# Segment Wise Total Profit
y2_prof = df.groupby(['Segment'])['Profit'].sum()
y2_prof
# Out:
# Segment
# Consumer       742695
# Corporate      437322
# Home Office    274582
# Name: Profit, dtype: int64

# %%
# Segment Wise Total Discount
y2_disc = df.groupby(['Segment'])['Discount'].sum()
y2_disc
# Out:
# Segment
# Consumer       3807.942
# Corporate      2205.284
# Home Office    1316.402
# Name: Discount, dtype: float64

# %%
fig,(b1,b2,b3) = plt.subplots(1,3,figsize=(20,6))
b1.bar(s1,y2,color = ['green','red','blue'])
b2.bar(s1,y2_prof, color = ['green','red','blue'])
b3.bar(s1,y2_disc,color = ['green','red','blue'])
b1.set_title('Segment Wise Total Sales',fontsize=20)
b2.set_title('Segment Wise Total Profit',fontsize=20)
b3.set_title('Segment Wise Total Discount',fontsize=20)
plt.show()

# %% [markdown]
# ### Conclusion :
# Thus from this graphs we can say that Consumer Segment is performing good as we give more discount on this.
#
# So, in-order to increase sales and profit we need to gave discount to Corporate and Home-Office segment also.

# %% [markdown]
# ## Region Wise Total Sales and Profit Performance

# %%
r1=df['Region'].unique()
r1
# Out:
# array(['Central US', 'Oceania', 'Western Europe', 'Western Africa',
#        'Western US', 'Southern Asia', 'Western Asia', 'South America',
#        'Eastern Asia', 'Southern Europe', 'Eastern Africa',
#        'Eastern Europe', 'Northern Europe', 'Central America',
#        'Eastern US', 'Caribbean', 'Central Africa', 'Southeastern Asia',
#        'Southern US', 'North Africa', 'Southern Africa', 'Canada',
#        'Central Asia'], dtype=object)

# %% [markdown]
# ## Region Wise Total Sales

# %%
y3 = df.groupby(['Region'])['Sales'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,10))
s=sns.barplot(y='Region',x='Sales',data=y3)
plt.xlabel("Sales", fontsize =15)
plt.ylabel("Region",fontsize =15)
plt.title("Region Wise Total Salest",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ## Region Wise Total Profit

# %%
y3_prof = df.groupby(['Region'])['Profit'].sum().sort_values().reset_index()
plt.figure(figsize=(15,10))
s=sns.barplot(y='Region',x='Profit',data=y3_prof)
plt.xlabel("Profit", fontsize =15)
plt.ylabel("Region",fontsize =15)
plt.title("Region Wise Total Profit",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ## Region Wise Total Discount

# %%
y3_disc = df.groupby(['Region'])['Discount'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,10))
s=sns.barplot(y='Region',x='Discount',data=y3_disc)
plt.xlabel("Discount", fontsize =15)
plt.ylabel("Region",fontsize =15)
plt.title("Region Wise Total Discount",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ## Conclusion :
# from this graph we may say that Total sales and Profit is maximum in Western Europe Region ,Though we are giving more discount to Western Asia Region

# %% [markdown]
# ## Now we check for Correlation

# %%
numeric_features
# Out:
# ['Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Delivery Days',
#  'Order Month',
#  'Order Year']

# %%
compare=df.loc[:,['Sales','Quantity','Discount','Profit','Shipping Cost']]
compare
# Out:
#        Sales  Quantity  Discount  Profit  Shipping Cost
# 0        221         2       0.0      62             40
# 1       3709         9       0.1    -288            923
# 2       5175         9       0.1     919            915
# 3       2892         5       0.1     -96            910
# 4       2832         8       0.0     311            903
# ...      ...       ...       ...     ...            ...
# 51285     65         5       0.0       4              1
# 51286     16         5       0.2       3              1
# 51287      8         2       0.0       2              1
# 51288     13         2       0.0       2              1
# 51289     61         3       0.0       1              1
#
# [51287 rows x 5 columns]

# %%
#Plotting Heatmap for better understanding of above numerical data
compare=df.loc[:,['Sales','Quantity','Discount','Profit','Shipping Cost']]
correlation=compare.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
plt.show()

# %% [markdown]
# ### Conclusion :
# Thus From this we may say that ,
#
# * Sales and Profit are Possitively Correlated
#
# * Discount and Profit are Negatively Correlated
#
# * Discount and Sales are Negatively Correlated

# %% [markdown]
# ### Total shipping cost of all category.

# %%
a=df.groupby('Category',as_index=False)['Shipping Cost'].sum()

plt.figure(figsize=(15,5))
s=sns.barplot(x='Category',y='Shipping Cost',data=a)
plt.xlabel("Category", fontsize =15)
plt.ylabel("Shipping Cost",fontsize =15)
plt.title("Shipping cost of category.",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### Top 5 customers, who make the most orders.

# %%
a=df['Customer Name'].value_counts(ascending=False).reset_index().head()

plt.figure(figsize=(15,5))
s=sns.barplot(x='index',y='Customer Name',data=a)
plt.xlabel("Customer Name", fontsize =15)
plt.ylabel("Total Order",fontsize =15)
plt.title("Top 5 Customer by orders",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# ### 5 customers, who make the lowest orders.

# %%
b=df['Customer Name'].value_counts(ascending=True).reset_index().head()
plt.figure(figsize=(15,5))
s=sns.barplot(x='index',y='Customer Name',data=b)
plt.xlabel("Customer Name", fontsize =15)
plt.ylabel("Total Order",fontsize =15)
plt.title("5 lowest orders",fontsize =20)
for i in s.containers:
    s.bar_label(i)
plt.show()

# %% [markdown]
# #  Conclusion :
# ### >> The Highest order has come from the 'Technology' category and 'Binders' sub-category.
# ### >> The Highest sales has come from the 'Technology' category and 'Phones' sub-category.
# ### >> Highest sales and profit in United State Country, England State and New York city.
# ### >> The maximum order comes in the year '2015' and the maximum order comes in the 'november' month.
# ### >> Total sales and profit are maximum in Western Europe Region, maximum discount in Western Asia.
# ### >> The Highest shipping cost has come from the 'Technology' category.
# ### >> The most ordered customer is 'Muhammed Yedwab', who has placed 108 orders.
# ### >> The lowest ordered customer is 'Kai Rey', who has placed 7 orders.

# %% [markdown]
# # Thank You !
